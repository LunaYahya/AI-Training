# %%
print("hello")
# Out:
# hello

# %%
import numpy
import pandas
import matplotlib

print(numpy.__version__)
print(matplotlib.__version__)
print(pandas.__version__)
# Out:
# 2.4.6
# 3.11.0
# 3.0.3

# %% [markdown]
# this is the first note
