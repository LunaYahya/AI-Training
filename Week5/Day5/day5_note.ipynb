# %% [markdown]
# # Day 5 – Phase 3 Project Selection and Sprint 1 Planning
# ## Cardiac Patient Monitoring System
# ### Phase 3 Capstone Project
# This notebook describes the process of selecting Phase 3 project and planning Sprint 1 for that project.
# Today’s focus will not be to do a full implementation of the machine learning project but rather defining the scope of the project, problem statement, Definition of Done, Sprint 1 Backlog, estimate of effort, acceptance criteria, Sprint Goal and GitHub process flow.

# %% [markdown]
# ## Entering Phase 3
# During this phase, the intern develops one complete AI/ML project from raw data to a deployed and usable product.
# The project is developed across four one-week sprints.
# The main development flow is:
# Raw Data -->Data Understanding-->Data Cleaning-->Exploratory Data Analysis-->Preprocessing-->Feature Engineering-->Model Training-->Model Evaluation-->Final Model -->Deployment-->Documentation
# Week 5 closes Phase 2 by selecting the capstone project and planning Sprint 1.
# Therefore, the purpose of Day 5 is to make sure that the project has a clear scope and a clear plan before implementation starts.

# %% [markdown]
# ## 2. Capstone Project Options
# The six provided main capstone project types:
# 1. Customer Churn Prediction
# 2. House Price Prediction
# 3. Sentiment Analysis Tool
# 4. Image Classifier
# 5. Recommendation System
# 6. Fraud Detection Model
# Each option represents a different machine learning problem and can be selected based on the intern's interests, skills, and project requirements.

# %% [markdown]
# ### Overview of the Six Options
# | Project Type | Problem Type | Main Techniques |
# |---|---|---|
# | Customer Churn Prediction | Binary Classification | EDA, feature importance, threshold tuning |
# | House Price Prediction | Regression | Pipelines, polynomial features, regularization |
# | Sentiment Analysis | NLP Classification | TF-IDF or Transformers |
# | Image Classifier | Image Classification | CNNs, augmentation, transfer learning |
# | Recommendation System | Recommendation | Collaborative/content-based filtering |
# | Fraud Detection | Imbalanced Classification | SMOTE, precision-recall, SHAP |
# The selected project does not have to be one of these exact examples. A comparable real-world AI/ML use case can also be selected with mentor approval.

# %% [markdown]
# ## 3. Selected Capstone Project
# ### Project Name
# **Cardiac Patient Monitoring System**
# ### Dataset
# **Heart Disease Health Indicators Dataset**
# ### Problem Type
# **Binary Classification**
# ### Target Variable
# **HeartDiseaseorAttack**
# ### Target Classes
# - 0 - No heart disease indicator
# - 1 - Heart disease indicator
# ### Project Focus
# The project will use health, lifestyle, and demographic indicators to build a machine learning classification model that predicts the target class.
# The project is suitable for Phase 3 because it can be developed as a complete machine learning pipeline, including EDA, preprocessing, model training, evaluation, feature engineering, hyperparameter tuning, and deployment.

# %%
import pandas as pd
project_info = pd.DataFrame({
    "Project": ["Cardiac Patient Monitoring System"],
    "Dataset": ["Heart Disease Health Indicators Dataset"],
    "Problem Type": ["Binary Classification"],
    "Target Variable": ["HeartDiseaseorAttack"],
    "Target Classes": ["0 = No heart disease, 1 = Heart disease"]})
project_info
# Out:
#                              Project                                  Dataset  \
# 0  Cardiac Patient Monitoring System  Heart Disease Health Indicators Dataset
#
#             Problem Type       Target Variable  \
# 0  Binary Classification  HeartDiseaseorAttack
#
#                             Target Classes
# 0  0 = No heart disease, 1 = Heart disease

# %% [markdown]
# ### Reason for Choosing a Specific Project
# The chosen project is built on the basis of the Heart Disease Health Indicators Dataset that had already been studied during the past training weeks.
# The reuse of the project is advantageous since:
# - The dataset has already been studied.
# - data cleaning has already been done.
# - Exploratory Data Analysis has already been conducted.
# - Classification methods have already been used.
# - Several performance metrics have already been considered.
# - The project can be continued up to the full-fledged machine learning system.
# However, the previous work will not simply be copied into Phase 3. It will be reviewed, cleaned, reorganized, and improved according to the Phase 3 professional requirements.
# The previous work provides a starting point, while Phase 3 focuses on building a reproducible, organized, and deployable project.

# %% [markdown]
# ## Problem Statement
# Heart disease is a significant issue concerning people's health and well-being, and various indicators of an individual's health and lifestyle can be found in datasets.
# The task for this project is to develop a predictive model by applying machine learning approaches, which should perform the binary classification of the `HeartDiseaseorAttack` target using the available features.
# The model will learn from existing data and classify the observation into one of the two classes.
# The present project is considered to be the machine learning prediction system rather than the medical diagnosis system.

# %% [markdown]
# ##  Project Objectives
# The main objectives of the project are:
# 1. Understand and analyze the Heart Disease Health Indicators Dataset.
# 2. Perform data cleaning and preprocessing.
# 3. Explore important patterns and relationships using EDA.
# 4. Build a reproducible baseline classification model.
# 5. Train and compare multiple classification models.
# 6. Evaluate models using appropriate classification metrics.
# 7. Perform feature engineering when appropriate.
# 8. Select a final model based on the evaluation results.
# 9. Save the trained model as a reusable model artifact.
# 10. Document the complete project in GitHub.

# %% [markdown]
# ## 7. Definition of Done
# ### What Does "Done" Mean?
# The project is considered complete only when it satisfies the professional baseline defined for Phase 3.
# Finishing the machine learning code alone is not enough.
# The final project must contain a complete and reproducible machine learning workflow from data exploration to deployment.

# %% [markdown]
# ### Definition of Done Checklist
# The project will be considered Done when all of the following requirements are satisfied:
# - [x] A clean and documented Jupyter Notebook covers the ML pipeline.
# - [x] Data cleaning and preprocessing are documented.
# - [x] Exploratory Data Analysis is completed and documented.
# - [x] A baseline model has been trained.
# - [x] Multiple models have been evaluated.
# - [x] Classification metrics and confusion matrix have been reported.
# - [x] Feature engineering and hyperparameter tuning have been performed.
# - [ ] Final model is selected and finalized for Phase 3.
# - [ ] The final trained model is saved as a model artifact.
# - [ ] A working deployment is available through a public URL.
# - [ ] The Phase 3 GitHub repository has a clean and complete README.
# - [x] `requirements.txt` has been prepared.
# - [ ] The Phase 3 project structure is fully organized.
# - [ ] A final technical write-up is completed.
# - [ ] The complete Phase 3 development follows the feature-branch and Pull Request workflow.
